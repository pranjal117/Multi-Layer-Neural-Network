# %%
import importlib, importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# %%
MLNN = module_from_file("myclasses", "MLNN.py")

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d 
import sklearn
from sklearn.model_selection import train_test_split
from itertools import permutations 
from scipy import stats
import random

# %%
def logistic(beta, x):
    return 1/(1 + np.exp(-beta*x))
    
def tanh(beta, x):
    return (np.exp(beta*x) - np.exp(beta*x))/(np.exp(beta*x) + np.exp(-beta*x))

def linear(beta, x):
    return x

def softmax(beta, x):
    return (np.exp(x.T)/sum(np.exp(x.T))).T


def act(actFun, vec, β):
    if(actFun == 'logistic'):
        return logistic(β, vec)
    elif(actFun == 'tanh'):
        return tanh(β, vec)
    elif(actFun == 'linear'):
        return linear(β, vec)
    elif(actFun == 'softmax'):
        return softmax(β, vec)
    else:
        print('No such activation function exists')
        return

# %%
def plotsAtHiddens(data ,W, actFuns, β):
    
    N, d = data.shape
        
    o = np.ones(N)
    o = np.reshape(o, (N, 1))
        
    S = []
    S.append(data)
        
    for h in range(len(actFuns)):
            
        dth = np.hstack((o, S[h]))
                
        Ah = np.dot(dth, W[h].T)
        Sh = act(actFuns[h], Ah, β)
        
        S.append(Sh)
        
        n, D = Sh.shape
        
        for i in range(D):
            
            if(d == 1):
                plt.scatter(data[:,0], Sh[:,i], s = 1)
                plt.title('%d th Node of %d th Layer'%(i+1,h+1))
                plt.show()
                
            elif(d == 2):
                
                fig = plt.figure() 
                ax = plt.axes(projection ='3d') 
    
                ax.scatter(data[:,0], data[:,1], Sh[:,i], c = 'c', s = 1) 
                plt.title('%d th Node of %d th Layer'%(i+1,h+1))
                plt.show()

# %%
class ReadData(object):
    
    def __init__(self, data, file, dim):
        
        self.file = file
            
        df = pd.read_csv(file, header = None)
        data = df.values
            
        self.data = data 
        self.dim = dim


    def plotData(self):
        
        if(self.dim == 2):
            
            X = self.data[:,self.dim-2]
            Y = self.data[:, self.dim-1]
            plt.scatter(X, Y, s = 1) 
            
        if(self.dim == 3):
            
            x = self.data[:, self.dim-3]
            y = self.data[:, self.dim-2]
            z = self.data[:, self.dim-1]
            
            fig = plt.figure() 
            ax = plt.axes(projection ='3d')
            ax.scatter(x, y, z, c = 'r', s = 1)
            
        plt.show() 


    def train_validation_test_split(self, perTrain, perVal, perTest):
            
        train, test = train_test_split(self.data, test_size=perTest, random_state=42, shuffle=True)
        train, val = train_test_split(train, test_size = (perVal/(perVal + perTrain)), random_state=42, shuffle=True)
            
        return train, val, test

# %% [markdown]
# # Univariate Data

# %%
dataset = ReadData([], 'Dataset/Regression/UnivariateData/17.csv', 2)
dataset.plotData()
trainData, valData, testData = dataset.train_validation_test_split(0.6,0.2,0.2)

# %%
X = trainData[:,:1]
Y = trainData[:,1:]

# %%
def checkParam(η, α, β, epochs, low, high):

    nn = MLNN.MLNN([1,3,3,1],['logistic','logistic','linear'], low, high)
    a,b = nn.fit(X, Y, η, α, β, epochs)

    plt.scatter(X,Y, s = 1)
    plt.scatter(X, nn.predict(X, β), s=1)
    plt.show()
    
    print('Error on Training data =', b[-1])

    x = valData[:,:1]
    y = valData[:,1:]
    predVal = nn.predict(x, β)
    plt.scatter(x, y, s=1)
    plt.scatter(x, predVal, s=1)
    plt.show()

    print('Error on Validation data =', np.sum(((y-predVal)**2)/(2*len(x))))
    
    return nn, a

# %%
nn, W = checkParam(0.0855, 0.4, 1, 600, -3, 3)
# Out:
# echo 0, error = 9.08
# echo 1, error = 5.52
# echo 2, error = 2.67
# echo 3, error = 1.55
# echo 4, error = 1.16
# echo 5, error = 1.04
# echo 6, error = 1.00
# echo 7, error = 0.99
# echo 8, error = 0.98
# echo 9, error = 0.98
# echo 10, error = 0.98
# echo 11, error = 0.98
# echo 12, error = 0.98
# echo 13, error = 0.98
# echo 14, error = 0.98
# echo 15, error = 0.98
# echo 16, error = 0.98
# echo 17, error = 0.98
# echo 18, error = 0.98
# echo 19, error = 0.98
# echo 20, error = 0.98
# echo 21, error = 0.98
# echo 22, error = 0.98
# echo 23, error = 0.98
# echo 24, error = 0.98
# echo 25, error = 0.98
# echo 26, error = 0.97
# echo 27, error = 0.97
# echo 28, error = 0.97
# echo 29, error = 0.97
# echo 30, error = 0.97
# echo 31, error = 0.97
# echo 32, error = 0.97
# echo 33, error = 0.97
# echo 34, error = 0.97
# echo 35, error = 0.97
# echo 36, error = 0.97
# echo 37, error = 0.97
# echo 38, error = 0.97
# echo 39, error = 0.97
# echo 40, error = 0.97
# echo 41, error = 0.97
# echo 42, error = 0.97
# echo 43, error = 0.97
# echo 44, error = 0.97
# echo 45, error = 0.97
# echo 46, error = 0.97
# echo 47, error = 0.96
# echo 48, error = 0.96
# echo 49, error = 0.96
# echo 50, error = 0.96
# echo 51, error = 0.96
# echo 52, error = 0.96
# echo 53, error = 0.96
# echo 54, error = 0.96
# echo 55, error = 0.96
# echo 56, error = 0.96
# echo 57, error = 0.96
# echo 58, error = 0.96
# echo 59, error = 0.96
# echo 60, error = 0.96
# echo 61, error = 0.96
# echo 62, error = 0.96
# echo 63, error = 0.96
# echo 64, error = 0.96
# echo 65, error = 0.96
# echo 66, error = 0.96
# echo 67, error = 0.96
# echo 68, error = 0.95
# echo 69, error = 0.95
# echo 70, error = 0.95
# echo 71, error = 0.95
# echo 72, error = 0.95
# echo 73, error = 0.95
# echo 74, error = 0.95
# echo 75, error = 0.95
# echo 76, error = 0.95
# echo 77, error = 0.95
# echo 78, error = 0.95
# echo 79, error = 0.95
# echo 80, error = 0.95
# echo 81, error = 0.95
# echo 82, error = 0.95
# echo 83, error = 0.95
# echo 84, error = 0.95
# echo 85, error = 0.95
# echo 86, error = 0.95
# echo 87, error = 0.95
# echo 88, error = 0.95
# echo 89, error = 0.94
# echo 90, error = 0.94
# echo 91, error = 0.94
# echo 92, error = 0.94
# echo 93, error = 0.94
# echo 94, error = 0.94
# echo 95, error = 0.94
# echo 96, error = 0.94
# echo 97, error = 0.94
# echo 98, error = 0.94
# echo 99, error = 0.94
# echo 100, error = 0.94
# echo 101, error = 0.94
# echo 102, error = 0.94
# echo 103, error = 0.94
# echo 104, error = 0.94
# echo 105, error = 0.94
# echo 106, error = 0.94
# echo 107, error = 0.94
# echo 108, error = 0.94
# echo 109, error = 0.94
# echo 110, error = 0.94
# echo 111, error = 0.94
# echo 112, error = 0.94
# echo 113, error = 0.94
# echo 114, error = 0.93
# echo 115, error = 0.93
# echo 116, error = 0.93
# echo 117, error = 0.93
# echo 118, error = 0.93
# echo 119, error = 0.93
# echo 120, error = 0.93
# echo 121, error = 0.93
# echo 122, error = 0.93
# echo 123, error = 0.93
# echo 124, error = 0.93
# echo 125, error = 0.93
# echo 126, error = 0.93
# echo 127, error = 0.93
# echo 128, error = 0.93
# echo 129, error = 0.93
# echo 130, error = 0.93
# echo 131, error = 0.93
# echo 132, error = 0.93
# echo 133, error = 0.93
# echo 134, error = 0.93
# echo 135, error = 0.93
# echo 136, error = 0.93
# echo 137, error = 0.93
# echo 138, error = 0.93
# echo 139, error = 0.93
# echo 140, error = 0.93
# echo 141, error = 0.93
# echo 142, error = 0.93
# echo 143, error = 0.93
# echo 144, error = 0.92
# echo 145, error = 0.92
# echo 146, error = 0.92
# echo 147, error = 0.92
# echo 148, error = 0.92
# echo 149, error = 0.92
# echo 150, error = 0.92
# echo 151, error = 0.92
# echo 152, error = 0.92
# echo 153, error = 0.92
# echo 154, error = 0.92
# echo 155, error = 0.92
# echo 156, error = 0.92
# echo 157, error = 0.92
# echo 158, error = 0.92
# echo 159, error = 0.92
# echo 160, error = 0.92
# echo 161, error = 0.92
# echo 162, error = 0.92
# echo 163, error = 0.92
# echo 164, error = 0.92
# echo 165, error = 0.92
# echo 166, error = 0.92
# echo 167, error = 0.92
# echo 168, error = 0.92
# echo 169, error = 0.92
# echo 170, error = 0.92
# echo 171, error = 0.92
# echo 172, error = 0.92
# echo 173, error = 0.92
# echo 174, error = 0.92
# echo 175, error = 0.91
# echo 176, error = 0.91
# echo 177, error = 0.91
# echo 178, error = 0.91
# echo 179, error = 0.91
# echo 180, error = 0.91
# echo 181, error = 0.91
# echo 182, error = 0.91
# echo 183, error = 0.91
# echo 184, error = 0.91
# echo 185, error = 0.91
# echo 186, error = 0.91
# echo 187, error = 0.91
# echo 188, error = 0.91
# echo 189, error = 0.91
# echo 190, error = 0.91
# echo 191, error = 0.91
# echo 192, error = 0.91
# echo 193, error = 0.91
# echo 194, error = 0.91
# echo 195, error = 0.91
# echo 196, error = 0.91
# echo 197, error = 0.91
# echo 198, error = 0.91
# echo 199, error = 0.91
# echo 200, error = 0.91
# echo 201, error = 0.91
# echo 202, error = 0.91
# echo 203, error = 0.90
# echo 204, error = 0.90
# echo 205, error = 0.90
# echo 206, error = 0.90
# echo 207, error = 0.90
# echo 208, error = 0.90
# echo 209, error = 0.90
# echo 210, error = 0.90
# echo 211, error = 0.90
# echo 212, error = 0.90
# echo 213, error = 0.90
# echo 214, error = 0.90
# echo 215, error = 0.90
# echo 216, error = 0.90
# echo 217, error = 0.90
# echo 218, error = 0.90
# echo 219, error = 0.90
# echo 220, error = 0.90
# echo 221, error = 0.90
# echo 222, error = 0.90
# echo 223, error = 0.90
# echo 224, error = 0.90
# echo 225, error = 0.90
# echo 226, error = 0.90
# echo 227, error = 0.90
# echo 228, error = 0.89
# echo 229, error = 0.89
# echo 230, error = 0.89
# echo 231, error = 0.89
# echo 232, error = 0.89
# echo 233, error = 0.89
# echo 234, error = 0.89
# echo 235, error = 0.89
# echo 236, error = 0.89
# echo 237, error = 0.89
# echo 238, error = 0.89
# echo 239, error = 0.89
# echo 240, error = 0.89
# echo 241, error = 0.89
# echo 242, error = 0.89
# echo 243, error = 0.89
# echo 244, error = 0.89
# echo 245, error = 0.89
# echo 246, error = 0.89
# echo 247, error = 0.88
# echo 248, error = 0.88
# echo 249, error = 0.88
# echo 250, error = 0.88
# echo 251, error = 0.88
# echo 252, error = 0.88
# echo 253, error = 0.88
# echo 254, error = 0.88
# echo 255, error = 0.88
# echo 256, error = 0.88
# echo 257, error = 0.88
# echo 258, error = 0.88
# echo 259, error = 0.88
# echo 260, error = 0.87
# echo 261, error = 0.87
# echo 262, error = 0.87
# echo 263, error = 0.87
# echo 264, error = 0.87
# echo 265, error = 0.87
# echo 266, error = 0.87
# echo 267, error = 0.87
# echo 268, error = 0.87
# echo 269, error = 0.86
# echo 270, error = 0.86
# echo 271, error = 0.86
# echo 272, error = 0.86
# echo 273, error = 0.86
# echo 274, error = 0.86
# echo 275, error = 0.85
# echo 276, error = 0.85
# echo 277, error = 0.85
# echo 278, error = 0.85
# echo 279, error = 0.85
# echo 280, error = 0.84
# echo 281, error = 0.84
# echo 282, error = 0.84
# echo 283, error = 0.84
# echo 284, error = 0.83
# echo 285, error = 0.83
# echo 286, error = 0.83
# echo 287, error = 0.83
# echo 288, error = 0.82
# echo 289, error = 0.82
# echo 290, error = 0.82
# echo 291, error = 0.81
# echo 292, error = 0.81
# echo 293, error = 0.80
# echo 294, error = 0.80
# echo 295, error = 0.79
# echo 296, error = 0.79
# echo 297, error = 0.79
# echo 298, error = 0.78
# echo 299, error = 0.78
# echo 300, error = 0.77
# echo 301, error = 0.77
# echo 302, error = 0.76
# echo 303, error = 0.76
# echo 304, error = 0.75
# echo 305, error = 0.74
# echo 306, error = 0.74
# echo 307, error = 0.73
# echo 308, error = 0.73
# echo 309, error = 0.72
# echo 310, error = 0.72
# echo 311, error = 0.71
# echo 312, error = 0.71
# echo 313, error = 0.70
# echo 314, error = 0.70
# echo 315, error = 0.69
# echo 316, error = 0.69
# echo 317, error = 0.68
# echo 318, error = 0.68
# echo 319, error = 0.67
# echo 320, error = 0.67
# echo 321, error = 0.66
# echo 322, error = 0.66
# echo 323, error = 0.65
# echo 324, error = 0.65
# echo 325, error = 0.64
# echo 326, error = 0.63
# echo 327, error = 0.63
# echo 328, error = 0.62
# echo 329, error = 0.62
# echo 330, error = 0.61
# echo 331, error = 0.61
# echo 332, error = 0.61
# echo 333, error = 0.60
# echo 334, error = 0.60
# echo 335, error = 0.59
# echo 336, error = 0.59
# echo 337, error = 0.58
# echo 338, error = 0.58
# echo 339, error = 0.57
# echo 340, error = 0.57
# echo 341, error = 0.56
# echo 342, error = 0.56
# echo 343, error = 0.55
# echo 344, error = 0.55
# echo 345, error = 0.54
# echo 346, error = 0.54
# echo 347, error = 0.54
# echo 348, error = 0.53
# echo 349, error = 0.53
# echo 350, error = 0.52
# echo 351, error = 0.52
# echo 352, error = 0.51
# echo 353, error = 0.51
# echo 354, error = 0.50
# echo 355, error = 0.50
# echo 356, error = 0.50
# echo 357, error = 0.49
# echo 358, error = 0.49
# echo 359, error = 0.48
# echo 360, error = 0.48
# echo 361, error = 0.48
# echo 362, error = 0.47
# echo 363, error = 0.47
# echo 364, error = 0.46
# echo 365, error = 0.46
# echo 366, error = 0.46
# echo 367, error = 0.45
# echo 368, error = 0.45
# echo 369, error = 0.44
# echo 370, error = 0.44
# echo 371, error = 0.44
# echo 372, error = 0.43
# echo 373, error = 0.43
# echo 374, error = 0.42
# echo 375, error = 0.42
# echo 376, error = 0.42
# echo 377, error = 0.41
# echo 378, error = 0.41
# echo 379, error = 0.41
# echo 380, error = 0.40
# echo 381, error = 0.40
# echo 382, error = 0.40
# echo 383, error = 0.39
# echo 384, error = 0.39
# echo 385, error = 0.38
# echo 386, error = 0.38
# echo 387, error = 0.38
# echo 388, error = 0.37
# echo 389, error = 0.37
# echo 390, error = 0.37
# echo 391, error = 0.36
# echo 392, error = 0.36
# echo 393, error = 0.36
# echo 394, error = 0.35
# echo 395, error = 0.35
# echo 396, error = 0.35
# echo 397, error = 0.34
# echo 398, error = 0.34
# echo 399, error = 0.34
# echo 400, error = 0.33
# echo 401, error = 0.33
# echo 402, error = 0.33
# echo 403, error = 0.32
# echo 404, error = 0.32
# echo 405, error = 0.32
# echo 406, error = 0.31
# echo 407, error = 0.31
# echo 408, error = 0.31
# echo 409, error = 0.31
# echo 410, error = 0.30
# echo 411, error = 0.30
# echo 412, error = 0.30
# echo 413, error = 0.29
# echo 414, error = 0.29
# echo 415, error = 0.29
# echo 416, error = 0.28
# echo 417, error = 0.28
# echo 418, error = 0.28
# echo 419, error = 0.28
# echo 420, error = 0.27
# echo 421, error = 0.27
# echo 422, error = 0.27
# echo 423, error = 0.27
# echo 424, error = 0.26
# echo 425, error = 0.26
# echo 426, error = 0.26
# echo 427, error = 0.25
# echo 428, error = 0.25
# echo 429, error = 0.25
# echo 430, error = 0.25
# echo 431, error = 0.24
# echo 432, error = 0.24
# echo 433, error = 0.24
# echo 434, error = 0.24
# echo 435, error = 0.23
# echo 436, error = 0.23
# echo 437, error = 0.23
# echo 438, error = 0.23
# echo 439, error = 0.22
# echo 440, error = 0.22
# echo 441, error = 0.22
# echo 442, error = 0.22
# echo 443, error = 0.21
# echo 444, error = 0.21
# echo 445, error = 0.21
# echo 446, error = 0.21
# echo 447, error = 0.21
# echo 448, error = 0.20
# echo 449, error = 0.20
# echo 450, error = 0.20
# echo 451, error = 0.20
# echo 452, error = 0.19
# echo 453, error = 0.19
# echo 454, error = 0.19
# echo 455, error = 0.19
# echo 456, error = 0.19
# echo 457, error = 0.18
# echo 458, error = 0.18
# echo 459, error = 0.18
# echo 460, error = 0.18
# echo 461, error = 0.18
# echo 462, error = 0.17
# echo 463, error = 0.17
# echo 464, error = 0.17
# echo 465, error = 0.17
# echo 466, error = 0.17
# echo 467, error = 0.16
# echo 468, error = 0.16
# echo 469, error = 0.16
# echo 470, error = 0.16
# echo 471, error = 0.16
# echo 472, error = 0.16
# echo 473, error = 0.15
# echo 474, error = 0.15
# echo 475, error = 0.15
# echo 476, error = 0.15
# echo 477, error = 0.15
# echo 478, error = 0.15
# echo 479, error = 0.14
# echo 480, error = 0.14
# echo 481, error = 0.14
# echo 482, error = 0.14
# echo 483, error = 0.14
# echo 484, error = 0.14
# echo 485, error = 0.13
# echo 486, error = 0.13
# echo 487, error = 0.13
# echo 488, error = 0.13
# echo 489, error = 0.13
# echo 490, error = 0.13
# echo 491, error = 0.12
# echo 492, error = 0.12
# echo 493, error = 0.12
# echo 494, error = 0.12
# echo 495, error = 0.12
# echo 496, error = 0.12
# echo 497, error = 0.12
# echo 498, error = 0.12
# echo 499, error = 0.11
# echo 500, error = 0.11
# echo 501, error = 0.11
# echo 502, error = 0.11
# echo 503, error = 0.11
# echo 504, error = 0.11
# echo 505, error = 0.11
# echo 506, error = 0.10
# echo 507, error = 0.10
# echo 508, error = 0.10
# echo 509, error = 0.10
# echo 510, error = 0.10
# echo 511, error = 0.10
# echo 512, error = 0.10
# echo 513, error = 0.10
# echo 514, error = 0.10
# echo 515, error = 0.09
# echo 516, error = 0.09
# echo 517, error = 0.09
# echo 518, error = 0.09
# echo 519, error = 0.09
# echo 520, error = 0.09
# echo 521, error = 0.09
# echo 522, error = 0.09
# echo 523, error = 0.09
# echo 524, error = 0.08
# echo 525, error = 0.08
# echo 526, error = 0.08
# echo 527, error = 0.08
# echo 528, error = 0.08
# echo 529, error = 0.08
# echo 530, error = 0.08
# echo 531, error = 0.08
# echo 532, error = 0.08
# echo 533, error = 0.08
# echo 534, error = 0.07
# echo 535, error = 0.07
# echo 536, error = 0.07
# echo 537, error = 0.07
# echo 538, error = 0.07
# echo 539, error = 0.07
# echo 540, error = 0.07
# echo 541, error = 0.07
# echo 542, error = 0.07
# echo 543, error = 0.07
# echo 544, error = 0.07
# echo 545, error = 0.07
# echo 546, error = 0.06
# echo 547, error = 0.06
# echo 548, error = 0.06
# echo 549, error = 0.06
# echo 550, error = 0.06
# echo 551, error = 0.06
# echo 552, error = 0.06
# echo 553, error = 0.06
# echo 554, error = 0.06
# echo 555, error = 0.06
# echo 556, error = 0.06
# echo 557, error = 0.06
# echo 558, error = 0.06
# echo 559, error = 0.06
# echo 560, error = 0.05
# echo 561, error = 0.05
# echo 562, error = 0.05
# echo 563, error = 0.05
# echo 564, error = 0.05
# echo 565, error = 0.05
# echo 566, error = 0.05
# echo 567, error = 0.05
# echo 568, error = 0.05
# echo 569, error = 0.05
# echo 570, error = 0.05
# echo 571, error = 0.05
# echo 572, error = 0.05
# echo 573, error = 0.05
# echo 574, error = 0.05
# echo 575, error = 0.05
# echo 576, error = 0.05
# echo 577, error = 0.04
# echo 578, error = 0.04
# echo 579, error = 0.04
# echo 580, error = 0.04
# echo 581, error = 0.04
# echo 582, error = 0.04
# echo 583, error = 0.04
# echo 584, error = 0.04
# echo 585, error = 0.04
# echo 586, error = 0.04
# echo 587, error = 0.04
# echo 588, error = 0.04
# echo 589, error = 0.04
# echo 590, error = 0.04
# echo 591, error = 0.04
# echo 592, error = 0.04
# echo 593, error = 0.04
# echo 594, error = 0.04
# echo 595, error = 0.04
# echo 596, error = 0.04
# echo 597, error = 0.04
# echo 598, error = 0.03
# echo 599, error = 0.03
# Error on Training data = 0.03417100823077934
# Error on Validation data = 0.03351355957215001

# %%
Xtest = testData[:,:1]
Ytest = testData[:,1:]

predsTest = nn.predict(Xtest, 1)

plt.scatter(Xtest, Ytest, s = 1)
plt.scatter(Xtest, predsTest, s = 1)
plt.show()

print('MSE on test data =', np.sum(((Ytest-predsTest)**2)/(2*len(Ytest))))
# Out:
# MSE on test data = 0.036314477517432796

# %%
plt.scatter(Ytest, predsTest, s = 1)
plt.xlabel('Actual Output on Test Set')
plt.ylabel('Predicted Output on Test Set')
plt.show()

# %%
plotsAtHiddens(X, W, ['logistic','logistic','linear'], 1)

# %% [markdown]
# # Bivariate Data

# %%
dataset = ReadData([], 'Dataset/Regression/BivariateData/17.csv', 3)
dataset.plotData()
trainData, valData, testData = dataset.train_validation_test_split(0.6,0.2,0.2)

# %%
X1 = trainData[:,:1]
X2 = trainData[:,range(1,2)]
Y = trainData[:,2:]

X = trainData[:,:2]

# %%
def checkParam3d(η, α, β, epochs, low, high):

    nn = MLNN.MLNN([2,7,7,1],['logistic','logistic','linear'], low, high)
    a,b = nn.fit(X, Y, η, α, β, epochs)
    
    fig = plt.figure() 
    ax = plt.axes(projection ='3d') 
    
    ax.scatter(X1, X2, Y, c = 'c', s = 1) 
    ax.scatter(X1, X2, nn.predict(X, β), c = 'r', s = 1) 
    plt.show() 
    
    print('Error on Training data =', b[-1])

    x = valData[:,:2]
    y = valData[:,2:]
    predVal = nn.predict(x, β)
    
    fig = plt.figure() 
    ax = plt.axes(projection ='3d') 
    
    ax.scatter(x[:,:1], x[:,1:], y, c = 'c', s = 1) 
    ax.scatter(x[:,:1], x[:,1:], predVal, c = 'r', s = 1) 
    plt.show() 

    print('Error on Validation data =', np.sum(((y-predVal)**2)/(2*len(x))))
    
    return nn, a

# %%
nn, W = checkParam3d(0.0858, 0.4, 1, 600, -5, 5)
# Out:
# echo 0, error = 18.20
# echo 1, error = 12.71
# echo 2, error = 9.36
# echo 3, error = 8.26
# echo 4, error = 7.71
# echo 5, error = 7.26
# echo 6, error = 6.82
# echo 7, error = 6.35
# echo 8, error = 5.84
# echo 9, error = 5.23
# echo 10, error = 4.52
# echo 11, error = 3.87
# echo 12, error = 3.49
# echo 13, error = 3.31
# echo 14, error = 3.23
# echo 15, error = 3.18
# echo 16, error = 3.15
# echo 17, error = 3.13
# echo 18, error = 3.11
# echo 19, error = 3.10
# echo 20, error = 3.08
# echo 21, error = 3.06
# echo 22, error = 3.04
# echo 23, error = 3.02
# echo 24, error = 3.00
# echo 25, error = 2.97
# echo 26, error = 2.94
# echo 27, error = 2.90
# echo 28, error = 2.86
# echo 29, error = 2.82
# echo 30, error = 2.76
# echo 31, error = 2.70
# echo 32, error = 2.63
# echo 33, error = 2.56
# echo 34, error = 2.47
# echo 35, error = 2.37
# echo 36, error = 2.27
# echo 37, error = 2.17
# echo 38, error = 2.07
# echo 39, error = 1.96
# echo 40, error = 1.87
# echo 41, error = 1.78
# echo 42, error = 1.70
# echo 43, error = 1.62
# echo 44, error = 1.56
# echo 45, error = 1.50
# echo 46, error = 1.45
# echo 47, error = 1.40
# echo 48, error = 1.37
# echo 49, error = 1.33
# echo 50, error = 1.30
# echo 51, error = 1.28
# echo 52, error = 1.26
# echo 53, error = 1.24
# echo 54, error = 1.22
# echo 55, error = 1.21
# echo 56, error = 1.19
# echo 57, error = 1.18
# echo 58, error = 1.17
# echo 59, error = 1.16
# echo 60, error = 1.15
# echo 61, error = 1.14
# echo 62, error = 1.14
# echo 63, error = 1.13
# echo 64, error = 1.12
# echo 65, error = 1.12
# echo 66, error = 1.11
# echo 67, error = 1.11
# echo 68, error = 1.10
# echo 69, error = 1.09
# echo 70, error = 1.09
# echo 71, error = 1.09
# echo 72, error = 1.08
# echo 73, error = 1.08
# echo 74, error = 1.07
# echo 75, error = 1.07
# echo 76, error = 1.06
# echo 77, error = 1.06
# echo 78, error = 1.05
# echo 79, error = 1.05
# echo 80, error = 1.05
# echo 81, error = 1.04
# echo 82, error = 1.04
# echo 83, error = 1.03
# echo 84, error = 1.03
# echo 85, error = 1.02
# echo 86, error = 1.02
# echo 87, error = 1.01
# echo 88, error = 1.01
# echo 89, error = 1.00
# echo 90, error = 1.00
# echo 91, error = 0.99
# echo 92, error = 0.98
# echo 93, error = 0.98
# echo 94, error = 0.97
# echo 95, error = 0.96
# echo 96, error = 0.96
# echo 97, error = 0.95
# echo 98, error = 0.94
# echo 99, error = 0.93
# echo 100, error = 0.93
# echo 101, error = 0.92
# echo 102, error = 0.91
# echo 103, error = 0.90
# echo 104, error = 0.89
# echo 105, error = 0.88
# echo 106, error = 0.88
# echo 107, error = 0.87
# echo 108, error = 0.86
# echo 109, error = 0.85
# echo 110, error = 0.84
# echo 111, error = 0.84
# echo 112, error = 0.83
# echo 113, error = 0.82
# echo 114, error = 0.82
# echo 115, error = 0.81
# echo 116, error = 0.80
# echo 117, error = 0.80
# echo 118, error = 0.79
# echo 119, error = 0.79
# echo 120, error = 0.78
# echo 121, error = 0.78
# echo 122, error = 0.77
# echo 123, error = 0.77
# echo 124, error = 0.77
# echo 125, error = 0.76
# echo 126, error = 0.76
# echo 127, error = 0.75
# echo 128, error = 0.75
# echo 129, error = 0.75
# echo 130, error = 0.74
# echo 131, error = 0.74
# echo 132, error = 0.74
# echo 133, error = 0.74
# echo 134, error = 0.73
# echo 135, error = 0.73
# echo 136, error = 0.73
# echo 137, error = 0.72
# echo 138, error = 0.72
# echo 139, error = 0.72
# echo 140, error = 0.72
# echo 141, error = 0.71
# echo 142, error = 0.71
# echo 143, error = 0.71
# echo 144, error = 0.71
# echo 145, error = 0.71
# echo 146, error = 0.70
# echo 147, error = 0.70
# echo 148, error = 0.70
# echo 149, error = 0.70
# echo 150, error = 0.70
# echo 151, error = 0.69
# echo 152, error = 0.69
# echo 153, error = 0.69
# echo 154, error = 0.69
# echo 155, error = 0.69
# echo 156, error = 0.69
# echo 157, error = 0.68
# echo 158, error = 0.68
# echo 159, error = 0.68
# echo 160, error = 0.68
# echo 161, error = 0.68
# echo 162, error = 0.68
# echo 163, error = 0.68
# echo 164, error = 0.67
# echo 165, error = 0.67
# echo 166, error = 0.67
# echo 167, error = 0.67
# echo 168, error = 0.67
# echo 169, error = 0.67
# echo 170, error = 0.67
# echo 171, error = 0.66
# echo 172, error = 0.66
# echo 173, error = 0.66
# echo 174, error = 0.66
# echo 175, error = 0.66
# echo 176, error = 0.66
# echo 177, error = 0.66
# echo 178, error = 0.66
# echo 179, error = 0.66
# echo 180, error = 0.65
# echo 181, error = 0.65
# echo 182, error = 0.65
# echo 183, error = 0.65
# echo 184, error = 0.65
# echo 185, error = 0.65
# echo 186, error = 0.65
# echo 187, error = 0.65
# echo 188, error = 0.65
# echo 189, error = 0.64
# echo 190, error = 0.64
# echo 191, error = 0.64
# echo 192, error = 0.64
# echo 193, error = 0.64
# echo 194, error = 0.64
# echo 195, error = 0.64
# echo 196, error = 0.64
# echo 197, error = 0.64
# echo 198, error = 0.64
# echo 199, error = 0.64
# echo 200, error = 0.63
# echo 201, error = 0.63
# echo 202, error = 0.63
# echo 203, error = 0.63
# echo 204, error = 0.63
# echo 205, error = 0.63
# echo 206, error = 0.63
# echo 207, error = 0.63
# echo 208, error = 0.63
# echo 209, error = 0.63
# echo 210, error = 0.62
# echo 211, error = 0.62
# echo 212, error = 0.62
# echo 213, error = 0.62
# echo 214, error = 0.62
# echo 215, error = 0.62
# echo 216, error = 0.62
# echo 217, error = 0.62
# echo 218, error = 0.62
# echo 219, error = 0.62
# echo 220, error = 0.61
# echo 221, error = 0.61
# echo 222, error = 0.61
# echo 223, error = 0.61
# echo 224, error = 0.61
# echo 225, error = 0.61
# echo 226, error = 0.61
# echo 227, error = 0.61
# echo 228, error = 0.61
# echo 229, error = 0.60
# echo 230, error = 0.60
# echo 231, error = 0.60
# echo 232, error = 0.60
# echo 233, error = 0.60
# echo 234, error = 0.60
# echo 235, error = 0.60
# echo 236, error = 0.60
# echo 237, error = 0.60
# echo 238, error = 0.59
# echo 239, error = 0.59
# echo 240, error = 0.59
# echo 241, error = 0.59
# echo 242, error = 0.59
# echo 243, error = 0.59
# echo 244, error = 0.59
# echo 245, error = 0.58
# echo 246, error = 0.58
# echo 247, error = 0.58
# echo 248, error = 0.58
# echo 249, error = 0.58
# echo 250, error = 0.58
# echo 251, error = 0.57
# echo 252, error = 0.57
# echo 253, error = 0.57
# echo 254, error = 0.57
# echo 255, error = 0.57
# echo 256, error = 0.56
# echo 257, error = 0.56
# echo 258, error = 0.56
# echo 259, error = 0.56
# echo 260, error = 0.55
# echo 261, error = 0.55
# echo 262, error = 0.55
# echo 263, error = 0.55
# echo 264, error = 0.55
# echo 265, error = 0.54
# echo 266, error = 0.54
# echo 267, error = 0.54
# echo 268, error = 0.53
# echo 269, error = 0.53
# echo 270, error = 0.53
# echo 271, error = 0.53
# echo 272, error = 0.52
# echo 273, error = 0.52
# echo 274, error = 0.52
# echo 275, error = 0.51
# echo 276, error = 0.51
# echo 277, error = 0.50
# echo 278, error = 0.50
# echo 279, error = 0.50
# echo 280, error = 0.49
# echo 281, error = 0.49
# echo 282, error = 0.49
# echo 283, error = 0.48
# echo 284, error = 0.48
# echo 285, error = 0.47
# echo 286, error = 0.47
# echo 287, error = 0.47
# echo 288, error = 0.46
# echo 289, error = 0.46
# echo 290, error = 0.45
# echo 291, error = 0.45
# echo 292, error = 0.45
# echo 293, error = 0.44
# echo 294, error = 0.44
# echo 295, error = 0.43
# echo 296, error = 0.43
# echo 297, error = 0.43
# echo 298, error = 0.42
# echo 299, error = 0.42
# echo 300, error = 0.41
# echo 301, error = 0.41
# echo 302, error = 0.41
# echo 303, error = 0.40
# echo 304, error = 0.40
# echo 305, error = 0.39
# echo 306, error = 0.39
# echo 307, error = 0.39
# echo 308, error = 0.38
# echo 309, error = 0.38
# echo 310, error = 0.38
# echo 311, error = 0.37
# echo 312, error = 0.37
# echo 313, error = 0.37
# echo 314, error = 0.36
# echo 315, error = 0.36
# echo 316, error = 0.36
# echo 317, error = 0.35
# echo 318, error = 0.35
# echo 319, error = 0.35
# echo 320, error = 0.35
# echo 321, error = 0.34
# echo 322, error = 0.34
# echo 323, error = 0.34
# echo 324, error = 0.33
# echo 325, error = 0.33
# echo 326, error = 0.33
# echo 327, error = 0.33
# echo 328, error = 0.32
# echo 329, error = 0.32
# echo 330, error = 0.32
# echo 331, error = 0.32
# echo 332, error = 0.32
# echo 333, error = 0.31
# echo 334, error = 0.31
# echo 335, error = 0.31
# echo 336, error = 0.31
# echo 337, error = 0.31
# echo 338, error = 0.30
# echo 339, error = 0.30
# echo 340, error = 0.30
# echo 341, error = 0.30
# echo 342, error = 0.30
# echo 343, error = 0.29
# echo 344, error = 0.29
# echo 345, error = 0.29
# echo 346, error = 0.29
# echo 347, error = 0.29
# echo 348, error = 0.29
# echo 349, error = 0.28
# echo 350, error = 0.28
# echo 351, error = 0.28
# echo 352, error = 0.28
# echo 353, error = 0.28
# echo 354, error = 0.28
# echo 355, error = 0.28
# echo 356, error = 0.28
# echo 357, error = 0.27
# echo 358, error = 0.27
# echo 359, error = 0.27
# echo 360, error = 0.27
# echo 361, error = 0.27
# echo 362, error = 0.27
# echo 363, error = 0.27
# echo 364, error = 0.27
# echo 365, error = 0.26
# echo 366, error = 0.26
# echo 367, error = 0.26
# echo 368, error = 0.26
# echo 369, error = 0.26
# echo 370, error = 0.26
# echo 371, error = 0.26
# echo 372, error = 0.26
# echo 373, error = 0.26
# echo 374, error = 0.26
# echo 375, error = 0.25
# echo 376, error = 0.25
# echo 377, error = 0.25
# echo 378, error = 0.25
# echo 379, error = 0.25
# echo 380, error = 0.25
# echo 381, error = 0.25
# echo 382, error = 0.25
# echo 383, error = 0.25
# echo 384, error = 0.25
# echo 385, error = 0.25
# echo 386, error = 0.25
# echo 387, error = 0.25
# echo 388, error = 0.24
# echo 389, error = 0.24
# echo 390, error = 0.24
# echo 391, error = 0.24
# echo 392, error = 0.24
# echo 393, error = 0.24
# echo 394, error = 0.24
# echo 395, error = 0.24
# echo 396, error = 0.24
# echo 397, error = 0.24
# echo 398, error = 0.24
# echo 399, error = 0.24
# echo 400, error = 0.24
# echo 401, error = 0.24
# echo 402, error = 0.23
# echo 403, error = 0.23
# echo 404, error = 0.23
# echo 405, error = 0.23
# echo 406, error = 0.23
# echo 407, error = 0.23
# echo 408, error = 0.23
# echo 409, error = 0.23
# echo 410, error = 0.23
# echo 411, error = 0.23
# echo 412, error = 0.23
# echo 413, error = 0.23
# echo 414, error = 0.23
# echo 415, error = 0.23
# echo 416, error = 0.23
# echo 417, error = 0.22
# echo 418, error = 0.22
# echo 419, error = 0.22
# echo 420, error = 0.22
# echo 421, error = 0.22
# echo 422, error = 0.22
# echo 423, error = 0.22
# echo 424, error = 0.22
# echo 425, error = 0.22
# echo 426, error = 0.22
# echo 427, error = 0.22
# echo 428, error = 0.22
# echo 429, error = 0.22
# echo 430, error = 0.22
# echo 431, error = 0.22
# echo 432, error = 0.22
# echo 433, error = 0.22
# echo 434, error = 0.22
# echo 435, error = 0.21
# echo 436, error = 0.21
# echo 437, error = 0.21
# echo 438, error = 0.21
# echo 439, error = 0.21
# echo 440, error = 0.21
# echo 441, error = 0.21
# echo 442, error = 0.21
# echo 443, error = 0.21
# echo 444, error = 0.21
# echo 445, error = 0.21
# echo 446, error = 0.21
# echo 447, error = 0.21
# echo 448, error = 0.21
# echo 449, error = 0.21
# echo 450, error = 0.21
# echo 451, error = 0.21
# echo 452, error = 0.20
# echo 453, error = 0.20
# echo 454, error = 0.20
# echo 455, error = 0.20
# echo 456, error = 0.20
# echo 457, error = 0.20
# echo 458, error = 0.20
# echo 459, error = 0.20
# echo 460, error = 0.20
# echo 461, error = 0.20
# echo 462, error = 0.20
# echo 463, error = 0.20
# echo 464, error = 0.20
# echo 465, error = 0.20
# echo 466, error = 0.20
# echo 467, error = 0.20
# echo 468, error = 0.20
# echo 469, error = 0.20
# echo 470, error = 0.20
# echo 471, error = 0.19
# echo 472, error = 0.19
# echo 473, error = 0.19
# echo 474, error = 0.19
# echo 475, error = 0.19
# echo 476, error = 0.19
# echo 477, error = 0.19
# echo 478, error = 0.19
# echo 479, error = 0.19
# echo 480, error = 0.19
# echo 481, error = 0.19
# echo 482, error = 0.19
# echo 483, error = 0.19
# echo 484, error = 0.19
# echo 485, error = 0.19
# echo 486, error = 0.19
# echo 487, error = 0.19
# echo 488, error = 0.19
# echo 489, error = 0.19
# echo 490, error = 0.19
# echo 491, error = 0.18
# echo 492, error = 0.18
# echo 493, error = 0.18
# echo 494, error = 0.18
# echo 495, error = 0.18
# echo 496, error = 0.18
# echo 497, error = 0.18
# echo 498, error = 0.18
# echo 499, error = 0.18
# echo 500, error = 0.18
# echo 501, error = 0.18
# echo 502, error = 0.18
# echo 503, error = 0.18
# echo 504, error = 0.18
# echo 505, error = 0.18
# echo 506, error = 0.18
# echo 507, error = 0.18
# echo 508, error = 0.18
# echo 509, error = 0.18
# echo 510, error = 0.18
# echo 511, error = 0.18
# echo 512, error = 0.18
# echo 513, error = 0.18
# echo 514, error = 0.18
# echo 515, error = 0.17
# echo 516, error = 0.17
# echo 517, error = 0.17
# echo 518, error = 0.17
# echo 519, error = 0.17
# echo 520, error = 0.17
# echo 521, error = 0.17
# echo 522, error = 0.17
# echo 523, error = 0.17
# echo 524, error = 0.17
# echo 525, error = 0.17
# echo 526, error = 0.17
# echo 527, error = 0.17
# echo 528, error = 0.17
# echo 529, error = 0.17
# echo 530, error = 0.17
# echo 531, error = 0.17
# echo 532, error = 0.17
# echo 533, error = 0.17
# echo 534, error = 0.17
# echo 535, error = 0.17
# echo 536, error = 0.17
# echo 537, error = 0.17
# echo 538, error = 0.17
# echo 539, error = 0.17
# echo 540, error = 0.17
# echo 541, error = 0.17
# echo 542, error = 0.17
# echo 543, error = 0.17
# echo 544, error = 0.17
# echo 545, error = 0.17
# echo 546, error = 0.17
# echo 547, error = 0.16
# echo 548, error = 0.16
# echo 549, error = 0.16
# echo 550, error = 0.16
# echo 551, error = 0.16
# echo 552, error = 0.16
# echo 553, error = 0.16
# echo 554, error = 0.16
# echo 555, error = 0.16
# echo 556, error = 0.16
# echo 557, error = 0.16
# echo 558, error = 0.16
# echo 559, error = 0.16
# echo 560, error = 0.16
# echo 561, error = 0.16
# echo 562, error = 0.16
# echo 563, error = 0.16
# echo 564, error = 0.16
# echo 565, error = 0.16
# echo 566, error = 0.16
# echo 567, error = 0.16
# echo 568, error = 0.16
# echo 569, error = 0.16
# echo 570, error = 0.16
# echo 571, error = 0.16
# echo 572, error = 0.16
# echo 573, error = 0.16
# echo 574, error = 0.16
# echo 575, error = 0.16
# echo 576, error = 0.16
# echo 577, error = 0.16
# echo 578, error = 0.16
# echo 579, error = 0.16
# echo 580, error = 0.16
# echo 581, error = 0.16
# echo 582, error = 0.16
# echo 583, error = 0.16
# echo 584, error = 0.16
# echo 585, error = 0.16
# echo 586, error = 0.16
# echo 587, error = 0.16
# echo 588, error = 0.16
# echo 589, error = 0.16
# echo 590, error = 0.16
# echo 591, error = 0.16
# echo 592, error = 0.16
# echo 593, error = 0.16
# echo 594, error = 0.16
# echo 595, error = 0.16
# echo 596, error = 0.16
# echo 597, error = 0.16
# echo 598, error = 0.16
# echo 599, error = 0.15
# Error on Training data = 0.15491251853513816
# Error on Validation data = 0.1618826533319567

# %%
Xtest = testData[:,:2]
Ytest = testData[:,2:]

predsTest = nn.predict(Xtest, 1)

fig = plt.figure() 
ax = plt.axes(projection ='3d') 
    
ax.scatter(Xtest[:,:1], Xtest[:,1:], Ytest, c = 'c', s = 1) 
ax.scatter(Xtest[:,:1], Xtest[:,1:], predsTest, c = 'r', s = 1) 
plt.show() 

print('MSE on test data =', np.sum(((Ytest-predsTest)**2)/(2*len(Ytest))))
# Out:
# MSE on test data = 0.15040403156604157

# %%
plt.scatter(Xtest[:,:1], Ytest, s = 1, c = 'c')
plt.scatter(Xtest[:,:1], predsTest, s = 1, c = 'brown')
plt.title('Predictions with respect to x1 variable')
plt.show()

# %%
plt.scatter(Xtest[:,1:], Ytest, s = 1, c = 'skyblue')
plt.scatter(Xtest[:,1:], predsTest, s = 1, c = 'brown')
plt.title('Predictions with respect to x2 variable')
plt.show()

# %%
plt.scatter(Ytest, predsTest, s = 1)
plt.xlabel('Actual Output on Test Set')
plt.ylabel('Predicted Output on Test Set')
plt.show()

# %%
plotsAtHiddens(X, W, ['logistic','logistic','linear'], 1)
